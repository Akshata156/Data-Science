# %% [markdown]
#  ### MULTIPLE LINEAR REGRESSION
# #### Assignment Task:
# Your task is to perform a multiple linear regression analysis to predict the price of Toyota corolla based on the given attributes.
#
# Taskes:
# .

# %% [markdown]
# 1) .Perform exploratory data analysis (EDA) to gain insights into the dataset. Provide visualizations and summary statistics of the variables. Pre process the data to apply the MLR.

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Akshata\OneDrive\Desktop\Assignment\MLR\ToyotaCorolla - MLR.csv")
df.head(20)
# Out:
#     Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  Cylinders  \
# 0   13500         23  46986    Diesel   90          0  2000      3          4
# 1   13750         23  72937    Diesel   90          0  2000      3          4
# 2   13950         24  41711    Diesel   90          0  2000      3          4
# 3   14950         26  48000    Diesel   90          0  2000      3          4
# 4   13750         30  38500    Diesel   90          0  2000      3          4
# 5   12950         32  61000    Diesel   90          0  2000      3          4
# 6   16900         27  94612    Diesel   90          0  2000      3          4
# 7   18600         30  75889    Diesel   90          0  2000      3          4
# 8   21500         27  19700    Petrol  192          0  1800      3          4
# 9   12950         23  71138    Diesel   69          0  1900      3          4
# 10  20950         25  31461    Petrol  192          0  1800      3          4
# ...

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
df.shape
# Out:
# (1436, 11)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df[['Price', 'Age_08_04', 'KM', 'HP', 'Weight']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Fuel_Type']=l.fit_transform(df['Fuel_Type'])

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986          1  90          0  2000      3          4
# 1  13750         23  72937          1  90          0  2000      3          4
# 2  13950         24  41711          1  90          0  2000      3          4
# 3  14950         26  48000          1  90          0  2000      3          4
# 4  13750         30  38500          1  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Separate features and target variable
x= df.drop(columns=['Price'])
y = df['Price']

# %% [markdown]
# 2) Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder,LabelEncoder
from sklearn.compose import ColumnTransformer

# OneHotEncode the categorical variable 'Fuel_Type'
x_encoded=pd.get_dummies(x,columns=['Fuel_Type'],drop_first=True)

#Split the dataset into training and testing sets (e.g., 80% training, 20% testing)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#Apply the transformation
#x_train_transformed=preprocessor.fit_transform(x_train)
#x_test_transformed=preprocessor.transform(x_test)

# %%
x_train.size,x_test.size,y_train.size,y_test.size
# Out:
# (11480, 2880, 1148, 288)

# %%
#Model 1: Baseline model with all features
model1=LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
coefficient1=pd.DataFrame({'features':x_train.columns,
                           'coefficient':model1.coef_})

intercept1=model1.intercept_

print('model1 coefficient1:')
print(coefficient1)
print(f"Intercept: {intercept1}\n")
# Out:
# model1 coefficient1:
#     features   coefficient
# 0  Age_08_04 -1.214362e+02
# 1         KM -1.693560e-02
# 2  Fuel_Type  8.620564e+02
# 3         HP  2.065828e+01
# 4  Automatic  2.451969e+02
# 5         cc -7.351539e-02
# 6      Doors -3.627965e+01
# 7  Cylinders  1.023182e-12
# 8      Gears  5.302820e+02
# 9     Weight  2.351064e+01
# Intercept: -12636.278112384865

# %%
#model 2:exclide doors and cylinders from the model
x_train2=x_train.drop(columns=['Doors','Cylinders'])
x_test2=x_test.drop(columns=['Doors','Cylinders'])

model2=LinearRegression()
model2.fit(x_train2,y_train)
# Out:
# LinearRegression()

# %%
coefficient2=pd.DataFrame({'features':x_train2.columns,
                           'coefficient':model2.coef_})

intercept2=model2.intercept_

print('model2 coefficient1:')
print(coefficient2)
print(f"Intercept: {intercept2}\n")
# Out:
# model2 coefficient1:
#     features  coefficient
# 0  Age_08_04  -121.461006
# 1         KM    -0.017010
# 2  Fuel_Type   839.612057
# 3         HP    20.613488
# 4  Automatic   257.226821
# 5         cc    -0.072886
# 6      Gears   566.624645
# 7     Weight    23.219068
# Intercept: -12601.660044881577

# %%
#model3= log-transform the target variable price
y_train_log=np.log(y_train)
y_test_log=np.log(y_test)

model3=LinearRegression()
model3.fit(x_train,y_train_log)


coefficients3 = pd.DataFrame({
    'Feature': x_train.columns,
    'Coefficient': model3.coef_
})
intercept3 = model3.intercept_

print("Model 3 Coefficients (Log-Transformed Price):")
print(coefficients3)
print(f"Intercept: {intercept3}\n")
# Out:
# Model 3 Coefficients (Log-Transformed Price):
#      Feature   Coefficient
# 0  Age_08_04 -1.037281e-02
# 1         KM -1.704402e-06
# 2  Fuel_Type  4.202492e-02
# 3         HP  1.698464e-03
# 4  Automatic  3.912879e-02
# 5         cc -4.290547e-07
# 6      Doors  8.949140e-03
# 7  Cylinders  1.110223e-16
# 8      Gears  7.368967e-02
# 9     Weight  1.220604e-03
# Intercept: 7.9644710431291355

# %%
#evaluate the model
from sklearn.metrics import mean_squared_error,r2_score

#predicts for all models
y_pred1=model1.predict(x_test)
y_pred2=model2.predict(x_test2)
y_pred3=np.exp(model3.predict(x_test))   # Inverse log transform for Model 3 predictions


#model 1 evaluation
mse_1=mean_squared_error(y_test,y_pred1)
r2_1=r2_score(y_test,y_pred1)
print(f'model1-MSE:{mse_1},R2:{r2_1}')

#model 2 evaluation
mse_2=mean_squared_error(y_test,y_pred2)
r2_2=r2_score(y_test,y_pred2)
print(f'model2-MSE:{mse_2},R2:{r2_2}')

#model 3 evaluation
mse_3=mean_squared_error(y_test,y_pred3)
r2_3=r2_score(y_test,y_pred3)
print(f'model3-MSE:{mse_3},R2:{r2_3}')
# Out:
# model1-MSE:2096851.1400177148,R2:0.8428476112017994
# model2-MSE:2095592.563357342,R2:0.842941937558539
# model3-MSE:1530102.2008577343,R2:0.885323659185389

# %% [markdown]
# 5.Apply Lasso and Ridge methods on the model.

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score

# Lasso Regression
lasso = Lasso(alpha=1.0)  # You can tune the alpha parameter
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)

# Ridge Regression
ridge = Ridge(alpha=1.0)  # You can tune the alpha parameter
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)

# Lasso evaluation
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)
print(f"Lasso Regression - MSE: {mse_lasso}, R2: {r2_lasso}")

# Ridge evaluation
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)
print(f"Ridge Regression - MSE: {mse_ridge}, R2: {r2_ridge}")

# Display the coefficients for Lasso and Ridge
lasso_coefficients = pd.DataFrame({'Feature': X_train.columns,
                                    'Lasso Coefficient': lasso.coef_})

ridge_coefficients = pd.DataFrame({'Feature': X_train.columns,
                                    'Ridge Coefficient': ridge.coef_})

print("\nLasso Coefficients:")
print(lasso_coefficients)

print("\nRidge Coefficients:")
print(ridge_coefficients)
# Out:
# Lasso Regression - MSE: 2195387.2460865392, R2: 0.8354626403967389
# Ridge Regression - MSE: 2199746.3702333346, R2: 0.835135937771234
#
# Lasso Coefficients:
#         Feature  Lasso Coefficient
# 0     Age_08_04        -120.798032
# 1            KM          -0.016326
# 2            HP          14.559220
# 3     Automatic         133.401454
# 4            cc          -0.032399
# 5         Doors         -58.673161
# 6     Cylinders           0.000000
# 7         Gears         522.177477
# 8        Weight          25.721963
# 9   Fuel_Type_1         -32.310126
# 10  Fuel_Type_2        1364.391707
#
# Ridge Coefficients:
#         Feature  Ridge Coefficient
# 0     Age_08_04        -120.779659
# 1            KM          -0.016324
# 2            HP          14.141834
# 3     Automatic         146.907470
# 4            cc          -0.030509
# 5         Doors         -59.905791
# 6     Cylinders           0.000000
# 7         Gears         542.272328
# 8        Weight          25.821019
# ...

# %% [markdown]
# * You can compare the MSE and R² scores of each model to determine which performs best.
# * Model 3 might perform better if there is significant skewness in the price data, while Model 2 aims for a more interpretable model with fewer features.
